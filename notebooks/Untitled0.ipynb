# %% [markdown]
# # PGCView Image Prediction Pipeline
# This Python notebook will allow you to load the PGC View model API endpoints, upload your images, and then process them.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Grab the pipeline code from GitHub
# !git clone https://github.com/BoMeyering/regen_pgc_inference_pipeline.git
# %cd regen_pgc_inference_pipeline/
# Out:
# Cloning into 'regen_pgc_inference_pipeline'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 73 (delta 33), reused 45 (delta 12), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 27.21 MiB | 21.72 MiB/s, done.
# Resolving deltas: 100% (33/33), done.
# /content/regen_pgc_inference_pipeline

# %% [markdown]
# # Library Imports and Endpoint Configuration
# Do not modify these cells, just run them

# %%
# Imports
# import os
# import sys
# src_path = os.path.abspath('src')
# sys.path.append(src_path)

# import requests
# import cv2
# import polars as pl
# import pandas as pd
# import numpy as np
# from tqdm import tqdm
# import asyncio
# import aiohttp
# import time
# import glob
# import csv
# from glob import glob

from pipeline import run_pipeline, get_filenames
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.18 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
images = get_filenames('assets/images')
images
# Out:
# ['fe39c9fa-b2a0-451f-9e7f-55d119a62c1d.jpg',
#  'fe58af90-138d-4341-ba1c-f4af3352f1ca.jpg',
#  '72649807-5735-451d-834a-5ab80be1396f.jpg',
#  'Ta00141.jpg']

# %%
run_pipeline(images)
# Out:
# Processing image fe39c9fa-b2a0-451f-9e7f-55d119a62c1d.jpg:   0%|          | 0/4 [00:00<?, ?it/s]/content/regen_pgc_inference_pipeline/pipeline.py:165: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, prop_df], ignore_index=True)
# Processing image Ta00141.jpg:  75%|███████▌  | 3/4 [00:53<00:17, 17.91s/it]                             /content/regen_pgc_inference_pipeline/pipeline.py:156: RuntimeWarning: invalid value encountered in scalar divide
#   green_fraction /= total_grass_px
# /content/regen_pgc_inference_pipeline/pipeline.py:157: RuntimeWarning: invalid value encountered in scalar divide
#   brown_fraction /= total_grass_px
# Processing image Ta00141.jpg: 100%|██████████| 4/4 [01:11<00:00, 17.95s/it]
#                                    filename  background   quadrat  pgc_grass  \
# 0  fe39c9fa-b2a0-451f-9e7f-55d119a62c1d.jpg    0.643891  0.011517   0.151334
# 1  fe58af90-138d-4341-ba1c-f4af3352f1ca.jpg    0.542217  0.000000   0.256368
# 2  72649807-5735-451d-834a-5ab80be1396f.jpg    0.643051  0.020984   0.127448
# 3                               Ta00141.jpg    0.648315  0.025563   0.000000
#
#    pgc_clover  broadleaf_weed     maize  soybean  other_vegetation  \
# 0    0.002074        0.190189  0.000995      0.0               0.0
# 1    0.000000        0.201415  0.000000      0.0               0.0
# 2    0.060368        0.148149  0.000000      0.0               0.0
# 3    0.326121        0.000000  0.000000      0.0               0.0
#
#    active_grass  dormant_grass
# 0      0.870640       0.129360
# 1      0.914375       0.085625
# 2      0.983275       0.016725
# 3           NaN            NaN
