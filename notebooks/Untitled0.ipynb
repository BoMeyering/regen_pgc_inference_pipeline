# %% [markdown]
# # PGCView Image Prediction Pipeline
# This Python notebook will allow you to load the PGC View model API endpoints, upload your images, and then process them.
#
# Instructions:
# * Connect to a CPU instance using the menu at the top right of the notebook (no need to use a GPU runtime)
# * Once connected, go to the 'Files' directory on the left sidebar and upload all your images in 'RGPCV_fastapi/assets/images'
# * Click 'run' on each cell or use the toolbar and got to  'Runtime' -> 'Run all'
# * Wait for all the images to finish processing and then download image predictions and tabular data from 'output'.

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Grab the pipeline code from GitHub
# !git clone https://github.com/BoMeyering/regen_pgc_inference_pipeline.git
# %cd regen_pgc_inference_pipeline/
# Out:
# Cloning into 'regen_pgc_inference_pipeline'...
# remote: Enumerating objects: 83, done.
# remote: Total 83 (delta 0), reused 0 (delta 0), pack-reused 83 (from 1)
# Receiving objects: 100% (83/83), 41.92 MiB | 36.04 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# /content/regen_pgc_inference_pipeline

# %%
from pipeline import run_pipeline, get_filenames
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.18 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
# Grab all of the image filenames in 'assests/images'
images = get_filenames('assets/images')
images
# Out:
# ['PGC-species_2024-09-23_09-18-56_KY31_noendo_POST-1_2_5_grass grid.jpg',
#  '72649807-5735-451d-834a-5ab80be1396f.jpg',
#  'Ta00141.jpg',
#  'PGC-species_2024-09-23_09-09-16_KY31_noendo_POST-2_1_14_grass grid.jpg',
#  'oblique_rotated.JPG']

# %%
run_pipeline(images)
# Out:
# Processing image PGC-species_2024-09-23_09-18-56_KY31_noendo_POST-1_2_5_grass grid.jpg:   0%|          | 0/5 [00:00<?, ?it/s]
# Fewer than 2 markers predicted, returning predictions over entire image.
# /content/regen_pgc_inference_pipeline/pipeline.py:195: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, prop_df], ignore_index=True)
# Processing image oblique_rotated.JPG: 100%|██████████| 5/5 [01:08<00:00, 13.69s/it]
# Fewer than 2 markers predicted, returning predictions over entire image.
#                                             filename  background   quadrat  \
# 0  PGC-species_2024-09-23_09-18-56_KY31_noendo_PO...    0.030726  0.004853
# 1           72649807-5735-451d-834a-5ab80be1396f.jpg    0.643051  0.020984
# 2                                        Ta00141.jpg    0.648315  0.025563
# 3  PGC-species_2024-09-23_09-09-16_KY31_noendo_PO...    0.065997  0.000286
# 4                                oblique_rotated.JPG    0.273955  0.000065
#
#    pgc_grass  pgc_clover  broadleaf_weed     maize  soybean  other_vegetation  \
# 0   0.890619    0.001904        0.000000  0.071898      0.0               0.0
# 1   0.127448    0.060368        0.148149  0.000000      0.0               0.0
# 2   0.000000    0.326121        0.000000  0.000000      0.0               0.0
# 3   0.931860    0.000000        0.000584  0.001273      0.0               0.0
# 4   0.302631    0.000000        0.416891  0.006457      0.0               0.0
#
#    active_grass  dormant_grass
# 0      0.802675       0.197325
# 1      0.983275       0.016725
# 2      0.000000       0.000000
# 3      0.691280       0.308720
# 4      0.660632       0.339368
