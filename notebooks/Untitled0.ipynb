# %% [markdown]
# # PGCView Image Prediction Pipeline

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Grab the pipeline code from GitHub
# !git clone https://github.com/BoMeyering/regen_pgc_inference_pipeline.git
# %cd regen_pgc_inference_pipeline/
# Out:
# Cloning into 'regen_pgc_inference_pipeline'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 58 (delta 21), reused 40 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (58/58), 27.20 MiB | 19.67 MiB/s, done.
# Resolving deltas: 100% (21/21), done.
# /content/regen_pgc_inference_pipeline

# %% [markdown]
# # Library Imports and Endpoint Configuration
# Do not modify these cells, just run them

# %%
# Imports
import os
import sys
src_path = os.path.abspath('src')
sys.path.append(src_path)

import requests
import cv2
import polars as pl
import pandas as pd
import numpy as np
from tqdm import tqdm
import asyncio
import aiohttp
import time
import glob
import csv
from glob import glob

from pipeline import run_pipeline, get_filenames
# Out:
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.18 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
images = get_filenames('assets/images')
images
# Out:
# ['fe39c9fa-b2a0-451f-9e7f-55d119a62c1d.jpg',
#  'fe58af90-138d-4341-ba1c-f4af3352f1ca.jpg',
#  '72649807-5735-451d-834a-5ab80be1396f.jpg',
#  'Ta00141.jpg']

# %%
run_pipeline(images)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Processing fe39c9fa-b2a0-451f-9e7f-55d119a62c1d.jpg
# dict_keys(['filename', 'data'])
#   0%|          | 0/4 [00:15<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-31f64d39ce42> in <cell line: 1>()
# ----> 1 run_pipeline(images)
#
# /content/regen_pgc_inference_pipeline/pipeline.py in run_pipeline(images)
#     135                 props, props_dict = class_proportions(preds_transformed)
#     136
# --> 137                 props_dict['filename'] = file
#     138
#     139                 # Green Brown Pixel Discrimination
#
# NameError: name 'file' is not defined
