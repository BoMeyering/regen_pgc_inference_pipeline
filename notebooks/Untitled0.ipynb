# %% [markdown]
# # PGCView Image Prediction Pipeline

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Grab the pipeline code from GitHub
# !git clone https://github.com/BoMeyering/regen_pgc_inference_pipeline.git
# %cd regen_pgc_inference_pipeline/
# Out:
# Cloning into 'regen_pgc_inference_pipeline'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 42 (delta 9), reused 35 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 27.20 MiB | 22.02 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/regen_pgc_inference_pipeline

# %% [markdown]
# # Library Imports and Endpoint Configuration
# Do not modify these cells, just run them

# %%
# Imports
import os
import sys
src_path = os.path.abspath('src')
sys.path.append(src_path)

import requests
import cv2
import polars as pl
import pandas as pd
import numpy as np
from tqdm import tqdm
import asyncio
import aiohttp
import time
import glob
import csv
from glob import glob

from pipeline import run_pipeline

# %%
images = glob()
